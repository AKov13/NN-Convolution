# %% [markdown]
# ### VGG 16 from Keras applications Probe

# %% [markdown]
# #### Links:
# Lecture:
# https://www.youtube.com/watch?v=Cuk25Vwp4RM&feature=youtu.be
#
# Keras doc:
# https://keras.io/api/applications/vgg/#vgg16-function

# %%
# Load Modules
from keras.applications.vgg16 import VGG16
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input, decode_predictions
import numpy as np

# %%
# Load the model
model = VGG16(weights="imagenet")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# 553467904/553467096 [==============================] - 116s 0us/step

# %%
# Load Image
img = image.load_img('testing_cat.jpg', target_size=(224, 224))

# %%
# ...just look at this
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x295813E8F28>

# %%
# Transform the image
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
# Recognition
preds = model.predict(x)

# %%
# Show results
decode_predictions(preds, top=3)[0]
# Out:
# [('n02124075', 'Egyptian_cat', 0.30605242),
#  ('n02123045', 'tabby', 0.25358075),
#  ('n02123159', 'tiger_cat', 0.16352695)]
